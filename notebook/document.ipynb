# %% [markdown]
# ### DATA INGESTION

# %%
from langchain_core.documents import Document
# Out:
# c:\Users\Kaush\OneDrive\Desktop\Ml\ML Practice\RAC_Prac\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
doc=Document(
    page_content=" this is the main text content",metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Garv",
        "date_created":"2026-05-08"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Garv', 'date_created': '2026-05-08'}, page_content=' this is the main text content')

# %%
## create a simple txt file

import os
os.makedirs("../data/text_files",exist_ok=True)
